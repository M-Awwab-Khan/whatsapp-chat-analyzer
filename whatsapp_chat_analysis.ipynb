# %% [markdown]
# <a href="https://colab.research.google.com/github/M-Awwab-Khan/whatsapp-chat-analysis/blob/main/whatsapp_chat_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import re
import pandas as pd

# %%
f = open('WhatsApp Chat with NED Software Community.txt', 'r', encoding='utf-8')

# %%
data = f.read()

# %%
print(data)
# Out:
# 10/12/23, 22:09 - Messages and calls are end-to-end encrypted. No one outside of this chat, not even WhatsApp, can read or listen to them. Tap to learn more.
# 11/7/19, 23:25 - ~ 😇 created group "NED Software Community 👩‍💻👨‍💻"
# 10/12/23, 22:09 - You joined using this group's invite link
# 10/12/23, 22:12 - +92 325 7625781 joined using this group's invite link
# 10/12/23, 22:13 - TOOBA NED joined using this group's invite link
# 10/12/23, 23:01 - Haris Masood NED joined using this group's invite link
# 10/13/23, 00:19 - +92 304 1028443 joined using this group's invite link
# 10/13/23, 00:32 - +92 325 3019383: <Media omitted>
# 10/13/23, 13:01 - ~ 𝐌𝐫. 𝐖𝐞𝐥𝐥 𝐆𝐫𝐨𝐨𝐦𝐞𝐝! 🤍 added Ahmer NED
# 10/13/23, 16:02 - Nabeed NED: Spark Electronix shop here
# 10/13/23, 16:02 - Nabeed NED: Special 10% Discount  Offer for NEDians!!
# If you are looking for Electronic Components...  Resistance sheet, Capacitor sheet,
# Breadboard, Multimeter Modules,Sensors,
# , and much more, all
# ...

# %%
pattern = '\d{1,2}/\d{1,2}/\d{2,4},\s\d{1,2}:\d{2}\s-\s'

# %%
messages = re.split(pattern, data)[1:]
messages
# Out:
# ['Messages and calls are end-to-end encrypted. No one outside of this chat, not even WhatsApp, can read or listen to them. Tap to learn more.\n',
#  '~\u202f😇 created group "NED Software Community 👩\u200d💻👨\u200d💻"\n',
#  "You joined using this group's invite link\n",
#  "+92 325 7625781 joined using this group's invite link\n",
#  "TOOBA NED joined using this group's invite link\n",
#  "Haris Masood NED joined using this group's invite link\n",
#  "+92 304 1028443 joined using this group's invite link\n",
#  '+92 325 3019383: <Media omitted>\n',
#  '~\u202f𝐌𝐫. 𝐖𝐞𝐥𝐥 𝐆𝐫𝐨𝐨𝐦𝐞𝐝! 🤍 added Ahmer NED\n',
#  'Nabeed NED: Spark Electronix shop here\n',
# ...

# %%
dates = re.findall(pattern, data)
dates
# Out:
# ['10/12/23, 22:09 - ',
#  '11/7/19, 23:25 - ',
#  '10/12/23, 22:09 - ',
#  '10/12/23, 22:12 - ',
#  '10/12/23, 22:13 - ',
#  '10/12/23, 23:01 - ',
#  '10/13/23, 00:19 - ',
#  '10/13/23, 00:32 - ',
#  '10/13/23, 13:01 - ',
#  '10/13/23, 16:02 - ',
#  '10/13/23, 16:02 - ',
#  '10/13/23, 16:02 - ',
#  '10/13/23, 16:02 - ',
#  '10/13/23, 17:16 - ',
#  '10/13/23, 17:53 - ',
#  '10/13/23, 18:27 - ',
#  '10/13/23, 18:27 - ',
#  '10/13/23, 18:28 - ',
#  '10/13/23, 18:29 - ',
#  '10/13/23, 18:31 - ',
#  '10/13/23, 18:32 - ',
#  '10/13/23, 18:34 - ',
#  '10/13/23, 18:35 - ',
#  '10/13/23, 18:36 - ',
#  '10/13/23, 18:39 - ',
#  '10/13/23, 18:39 - ',
#  '10/13/23, 18:40 - ',
#  '10/13/23, 19:19 - ',
#  '10/13/23, 19:20 - ',
#  '10/13/23, 19:20 - ',
#  '10/13/23, 23:33 - ',
#  '10/14/23, 09:29 - ',
#  '10/14/23, 09:38 - ',
#  '10/14/23, 09:39 - ',
#  '10/14/23, 09:40 - ',
#  '10/14/23, 09:51 - ',
#  '10/14/23, 09:52 - ',
#  '10/14/23, 09:57 - ',
#  '10/14/23, 09:57 - ',
#  '10/14/23, 09:57 - ',
# ...

# %%
df = pd.DataFrame({'user_message': messages, 'date': dates})
df['date'] = pd.to_datetime(df['date'], format='%m/%d/%y, %H:%M - ')
df.head()
# Out:
#                                         user_message                date
# 0  Messages and calls are end-to-end encrypted. N... 2023-10-12 22:09:00
# 1  ~ 😇 created group "NED Software Community 👩‍💻👨... 2019-11-07 23:25:00
# 2        You joined using this group's invite link\n 2023-10-12 22:09:00
# 3  +92 325 7625781 joined using this group's invi... 2023-10-12 22:12:00
# 4  TOOBA NED joined using this group's invite link\n 2023-10-12 22:13:00

# %%
df.iloc[550]
# Out:
# user_message    Abdul Karim CR NED: Program cancel\n
# date                             2023-10-26 23:59:00
# Name: 550, dtype: object

# %%
df.shape
# Out:
# (2084, 2)

# %%
users = []
messages = []

for message in df['user_message']:
  entry = re.split('([\w\W]+?):\s', message)
  if entry[1:]:
    users.append(entry[1])
    messages.append(entry[2])
  else:
    users.append('group_notification')
    messages.append(entry[0])


df['user'] = users
df['message'] = messages
df.head()
# Out:
#                                         user_message                date  \
# 0  Messages and calls are end-to-end encrypted. N... 2023-10-12 22:09:00
# 1  ~ 😇 created group "NED Software Community 👩‍💻👨... 2019-11-07 23:25:00
# 2        You joined using this group's invite link\n 2023-10-12 22:09:00
# 3  +92 325 7625781 joined using this group's invi... 2023-10-12 22:12:00
# 4  TOOBA NED joined using this group's invite link\n 2023-10-12 22:13:00
#
#                  user                                            message
# 0  group_notification  Messages and calls are end-to-end encrypted. N...
# 1  group_notification  ~ 😇 created group "NED Software Community 👩‍💻👨...
# 2  group_notification        You joined using this group's invite link\n
# 3  group_notification  +92 325 7625781 joined using this group's invi...
# 4  group_notification  TOOBA NED joined using this group's invite link\n

# %%
df.drop(columns=['user_message'], inplace=True)
df.head()
# Out:
#                  date                user  \
# 0 2023-10-12 22:09:00  group_notification
# 1 2019-11-07 23:25:00  group_notification
# 2 2023-10-12 22:09:00  group_notification
# 3 2023-10-12 22:12:00  group_notification
# 4 2023-10-12 22:13:00  group_notification
#
#                                              message
# 0  Messages and calls are end-to-end encrypted. N...
# 1  ~ 😇 created group "NED Software Community 👩‍💻👨...
# 2        You joined using this group's invite link\n
# 3  +92 325 7625781 joined using this group's invi...
# 4  TOOBA NED joined using this group's invite link\n
